# %% [markdown]
# <a href="https://colab.research.google.com/github/RZJournal/Machine-Learning-Discord-Bot/blob/main/Discord_Bot_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

plt.scatter(X, y);

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1])
])

model.compile(loss="mean_squared_error",
              optimizer="sgd")

# %%
model.fit(X, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 336ms/step - loss: 166.8064
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 79.1489
# Epoch 3/500
# 1/1 [==============================] - 0s 13ms/step - loss: 73.5559
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 71.1289
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 68.8908
# Epoch 6/500
# 1/1 [==============================] - 0s 11ms/step - loss: 66.7272
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 64.6318
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 62.6021
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 60.6362
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 58.7321
# Epoch 11/500
# 1/1 [==============================] - 0s 9ms/step - loss: 56.8877
# Epoch 12/500
# ...

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 180ms/step
# array([[27.000046]], dtype=float32)

# %%
model.save('/content/saved_model')

# %%
import shutil

# Zip the saved model directory
shutil.make_archive('/content/saved_model', 'zip', '/content/saved_model')
# Out:
# '/content/saved_model.zip'

# %%
from google.colab import files

files.download('/content/saved_model.zip')
