# %% [markdown]
# <a href="https://colab.research.google.com/github/RZJournal/Machine-Learning-Discord-Bot-Jupyter-Notebooks/blob/main/Discord_Bot_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

plt.scatter(X, y);

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=[1])
])

model.compile(loss="mean_squared_error",
              optimizer="sgd")

# %%
model.fit(X, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 7s 7s/step - loss: 505.9062
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 90.6619
# Epoch 3/500
# 1/1 [==============================] - 0s 10ms/step - loss: 72.7578
# Epoch 4/500
# 1/1 [==============================] - 0s 13ms/step - loss: 69.9053
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 67.6886
# Epoch 6/500
# 1/1 [==============================] - 0s 24ms/step - loss: 65.5622
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 63.5033
# Epoch 8/500
# 1/1 [==============================] - 0s 11ms/step - loss: 61.5091
# Epoch 9/500
# 1/1 [==============================] - 0s 20ms/step - loss: 59.5775
# Epoch 10/500
# 1/1 [==============================] - 0s 19ms/step - loss: 57.7066
# Epoch 11/500
# 1/1 [==============================] - 0s 11ms/step - loss: 55.8944
# Epoch 12/500
# ...

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 162ms/step
# array([[27.000046]], dtype=float32)

# %%
model.save('/content/saved_model')

# %%
import shutil

# Zip the saved model directory
shutil.make_archive('/content/saved_model', 'zip', '/content/saved_model')
# Out:
# '/content/saved_model.zip'

# %%
from google.colab import files

files.download('/content/saved_model.zip')
